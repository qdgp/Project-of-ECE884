# %% [markdown]
# # Tabel of Contents
#
# > 1. Abstract
# > 2. Introduction and Motivation
# >

# %% [markdown]
# # 1. Abstract

# %% [markdown]
# # 2. Introduction and Motivation

# %%
import os
import splitfolders 
import tensorflow as tf
import tensorflow_probability as tfp
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.optimizers import Adam
import pandas as pd

tfd = tfp.distributions
tfpl = tfp.layers

from tensorflow.keras.layers import Dense, Conv2D, Flatten, MaxPool2D, MaxPooling2D, Dropout, Activation

import shutil

import cv2
import numpy as np

# %%
# list the folders in the directory
print(os.listdir(r"C:\1. Ob\Simulations and Data Sets\Deeplearning\data set\archive (2)"))
# Out:
# ['flowers', 'levels', 'levels2', 'levels2.rar', 'levels3', 'resized_train', 'resized_train_cropped', 'trainLabels.csv', 'trainLabels_cropped.csv']

# %%
#os.mkdir('C:/1. Ob/Simulations and Data Sets/Deeplearning/data set/archive (2)/levels')

# %%
path = r'C:\1. Ob\Simulations and Data Sets\Deeplearning\data set\archive (2)'
labels = pd.read_csv(path+r'\trainLabels_cropped.csv')
labels
# Out:
#        Unnamed: 0  Unnamed: 0.1        image  level
# 0               0             0      10_left      0
# 1               1             1     10_right      0
# 2               2             2      13_left      0
# 3               3             3     13_right      0
# 4               4             4      15_left      1
# ...           ...           ...          ...    ...
# 35103       35104         35121  44347_right      0
# 35104       35105         35122   44348_left      0
# 35105       35106         35123  44348_right      0
# 35106       35107         35124   44349_left      0
# 35107       35108         35125  44349_right      1
#
# [35108 rows x 4 columns]

# %%
#for f in labels.level.unique():
#    os.mkdir('C:/1. Ob/Simulations and Data Sets/Deeplearning/data set/archive (2)/levels/{}'.format(f))

# %%
#for f in labels.level.unique():
    
#   df = labels.loc[labels['level'] == f]
#    l = df['image'].tolist()
#    for im in l:
#        shutil.copy(path+r'/resized_train_cropped/resized_train_cropped/{}.jpeg'.format(im), path+'/levels/{}'.format(f))

# %%
from PIL import Image
image1_dir = os.path.join(path+r'\levels2'+'/1/1145_left.jpeg')
img=Image.open(image1_dir)
w,h=img.size    # w=Width and h=Height
print("Width =",w,end="\t")
print("Height =",h)
import matplotlib.pyplot as plt

#show the image
plt.imshow(img)
# Out:
# Width = 1024	Height = 815

# %%
root_dir=os.path.join(path+r'\levels2')
batch_size=64
img_width=256
img_height=256
print(root_dir)
# Out:
# C:\1. Ob\Simulations and Data Sets\Deeplearning\data set\archive (2)\levels2

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

def image_generator(root_dir):
    
    datagen = ImageDataGenerator(rescale=1/255,
                                      #shear_range=0.2,
                                      #zoom_range=0.2,
                                      #horizontal_flip=True,
                                      #vertical_flip=True,
                                      validation_split=0.2)
  
    
    train_generator = datagen.flow_from_directory(root_dir,
                                  target_size = (img_width, img_height),
                                  batch_size = batch_size,
                                  class_mode = 'categorical',
                                  subset='training')
 
    
    test_generator = datagen.flow_from_directory(root_dir,
                                 target_size=(img_width, img_height),
                                 batch_size = batch_size,
                                 class_mode = 'categorical',
                                 subset='validation')    
    
    return train_generator, test_generator

# %%
train_generator, test_generator = image_generator(root_dir)
# Out:
# Found 2800 images belonging to 5 classes.
# Found 700 images belonging to 5 classes.

# %% [markdown]
# ## Bayesian Model 1

# %%
divergence_fn = lambda q,p,_:tfd.kl_divergence(q,p)/3457

model_bayes = Sequential([
    
    tfpl.Convolution2DReparameterization(input_shape=(img_width, img_height,3),padding="same",filters=8, kernel_size=16, activation='relu',
                                           kernel_prior_fn = tfpl.default_multivariate_normal_fn,
                                           kernel_posterior_fn=tfpl.default_mean_field_normal_fn(is_singular=False),
                                           kernel_divergence_fn = divergence_fn,
                                           bias_prior_fn = tfpl.default_multivariate_normal_fn,
                                           bias_posterior_fn=tfpl.default_mean_field_normal_fn(is_singular=False),
                                           bias_divergence_fn = divergence_fn),
    Conv2D(64, (3,3), activation='relu'),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(128, (3,3), activation='relu'),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Conv2D(256, (3,3), activation='relu'),
    Conv2D(256, (3,3), activation='relu'),
    Conv2D(256, (3,3), activation='relu'),
    Conv2D(256, (3,3), activation='relu'),
    Conv2D(256, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(512, activation='relu'),
    Dropout(0.2),
    tfpl.DenseReparameterization(units=tfpl.OneHotCategorical.params_size(5), activation=None,
                                    kernel_prior_fn = tfpl.default_multivariate_normal_fn,
                                    kernel_posterior_fn=tfpl.default_mean_field_normal_fn(is_singular=False),
                                    kernel_divergence_fn = divergence_fn,
                                    bias_prior_fn = tfpl.default_multivariate_normal_fn,
                                    bias_posterior_fn=tfpl.default_mean_field_normal_fn(is_singular=False),
                                    bias_divergence_fn = divergence_fn
                                ),
    tfpl.OneHotCategorical(5)
    
])
model_bayes.summary()
# Out:
# C:\Users\obaid\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:2281: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_reparameterization_2  (None, 256, 256, 8)       12304
# _________________________________________________________________
# conv2d_22 (Conv2D)           (None, 254, 254, 64)      4672
# _________________________________________________________________
# conv2d_23 (Conv2D)           (None, 252, 252, 64)      36928
# _________________________________________________________________
# max_pooling2d_12 (MaxPooling (None, 126, 126, 64)      0
# _________________________________________________________________
# conv2d_24 (Conv2D)           (None, 124, 124, 128)     73856
# _________________________________________________________________
# conv2d_25 (Conv2D)           (None, 122, 122, 128)     147584
# _________________________________________________________________
# max_pooling2d_13 (MaxPooling (None, 61, 61, 128)       0
# _________________________________________________________________
# conv2d_26 (Conv2D)           (None, 59, 59, 256)       295168
# _________________________________________________________________
# conv2d_27 (Conv2D)           (None, 57, 57, 256)       590080
# _________________________________________________________________
# conv2d_28 (Conv2D)           (None, 55, 55, 256)       590080
# _________________________________________________________________
# conv2d_29 (Conv2D)           (None, 53, 53, 256)       590080
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 51, 51, 256)       590080
# _________________________________________________________________
# max_pooling2d_14 (MaxPooling (None, 25, 25, 256)       0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 160000)            0
# _________________________________________________________________
# dense_6 (Dense)              (None, 512)               81920512
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_reparameterization_2 ( (None, 5)                 5130
# _________________________________________________________________
# one_hot_categorical_2 (OneHo multiple                  0
# =================================================================
# Total params: 84,856,474
# Trainable params: 84,856,474
# Non-trainable params: 0
# _________________________________________________________________

# %%
from tensorflow.keras.optimizers import Adam

def negative_log_likelihood(y_true, y_pred):
    return -y_pred.log_prob(y_true)

model_bayes.compile(loss = negative_log_likelihood,
              optimizer = Adam(learning_rate=0.005),
              metrics = ['accuracy'],
              experimental_run_tf_function = False)

# %%
# Training the model
history = model_bayes.fit(train_generator,
                                steps_per_epoch = train_generator.samples // batch_size,
                                validation_data = test_generator, 
                                validation_steps = test_generator.samples // batch_size,
                                epochs = 9)
# Out:
# Epoch 1/9
#  1/43 [..............................] - ETA: 23:58 - loss: 467174.3438 - accuracy: 0.2031
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-47-c3e142000d0e> in <module>
#       1 # Training the model
# ----> 2 history = model_bayes.fit(train_generator,
#       3                                 steps_per_epoch = train_generator.samples // batch_size,
#       4                                 validation_data = test_generator,
#       5                                 validation_steps = test_generator.samples // batch_size,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12, 3))
fig.suptitle("Bayesian Model 1's accuracy and Loss",fontsize=12)


ax1.plot(history1.history['accuracy'],label='train')
ax1.plot(history1.history['val_accuracy'],label='test')
ax1.title.set_text('model accuracy')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epoch')
ax1.legend()



ax2.plot(history1.history['loss'],label='train')
ax2.plot(history1.history['val_loss'],label='test')
ax2.title.set_text('model loss')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend()

# %% [markdown]
# ## Bayesian Model 2

# %%
divergence_fn = lambda q,p,_:tfd.kl_divergence(q,p)/train_generator.samples

model_bayes2 = tf.keras.Sequential([
    tf.keras.Input(shape=(img_width, img_height, 3),name="basket"),
    
    tfpl.Convolution2DFlipout(16, kernel_size=5, strides=(1,1), data_format="channels_last", 
                                    padding="same", activation=tf.nn.relu, name="conv_tfp_1a", 
                                    kernel_divergence_fn=divergence_fn),

    MaxPool2D(strides=(4,4), pool_size=(4,4), padding="same"),
    Conv2D(32, (3,3), activation='relu'),
    
    tfpl.Convolution2DFlipout(32, kernel_size=3, strides=(1,1), data_format="channels_last", 
                                    padding="same", activation=tf.nn.relu, name="conv_tfp_1b", 
                                    kernel_divergence_fn=divergence_fn),
    MaxPool2D(strides=(4,4), pool_size=(4,4), padding="same"),
    Conv2D(64, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    
    Dropout(0.2),
    tfpl.DenseFlipout(units=5, kernel_divergence_fn=divergence_fn),
    #tfpl.OneHotCategorical(5)
])

learning_rate = 1.0e-3


model_bayes2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_tfp_1a (Conv2DFlipout)  (None, 256, 256, 16)      2416
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 64, 64, 16)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 62, 62, 32)        4640
# _________________________________________________________________
# conv_tfp_1b (Conv2DFlipout)  (None, 62, 62, 32)        18464
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 64)        18496
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 7, 7, 64)          0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 3136)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              3212288
# _________________________________________________________________
# dense_3 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 512)               0
# _________________________________________________________________
# dense_flipout_1 (DenseFlipou (None, 5)                 5125
# =================================================================
# Total params: 3,786,229
# Trainable params: 3,786,229
# Non-trainable params: 0
# _________________________________________________________________

# %%
def negative_log_likelihood(y_true, y_pred):
    y_pred = tfp.distributions.MultivariateNormalTriL(y_pred)
    return -tf.reduce_mean(y_pred.log_prob(y_true))

# %%
model_bayes2.compile(loss = negative_log_likelihood,
              optimizer = Adam(learning_rate=learning_rate),
              metrics = ['accuracy'],
              experimental_run_tf_function = False)

# %%
# Training the model
history2 = model_bayes2.fit(train_generator,
                                steps_per_epoch = train_generator.samples // batch_size,
                                validation_data = test_generator, 
                                validation_steps = test_generator.samples // batch_size,
                                epochs = 90)
# Out:
# Epoch 1/90
# 43/43 [==============================] - 103s 2s/step - loss: 16.9902 - accuracy: 0.1750 - val_loss: 16.5482 - val_accuracy: 0.2016
# Epoch 2/90
# 43/43 [==============================] - 99s 2s/step - loss: 16.5044 - accuracy: 0.2034 - val_loss: 16.3654 - val_accuracy: 0.1953
# Epoch 3/90
# 43/43 [==============================] - 103s 2s/step - loss: 16.3212 - accuracy: 0.1997 - val_loss: 16.1842 - val_accuracy: 0.1734
# Epoch 4/90
# 43/43 [==============================] - 100s 2s/step - loss: 16.1375 - accuracy: 0.1942 - val_loss: 15.9982 - val_accuracy: 0.1969
# Epoch 5/90
# 43/43 [==============================] - 102s 2s/step - loss: 15.9533 - accuracy: 0.2029 - val_loss: 15.8139 - val_accuracy: 0.1750
# Epoch 6/90
# 43/43 [==============================] - 100s 2s/step - loss: 15.7663 - accuracy: 0.2249 - val_loss: 15.6281 - val_accuracy: 0.1781
# Epoch 7/90
# 43/43 [==============================] - 98s 2s/step - loss: 15.5827 - accuracy: 0.1999 - val_loss: 15.4446 - val_accuracy: 0.1859
# Epoch 8/90
# 43/43 [==============================] - 99s 2s/step - loss: 15.3969 - accuracy: 0.1992 - val_loss: 15.2571 - val_accuracy: 0.2328
# Epoch 9/90
# 43/43 [==============================] - 99s 2s/step - loss: 15.2138 - accuracy: 0.1844 - val_loss: 15.0736 - val_accuracy: 0.2000
# Epoch 10/90
# 43/43 [==============================] - 100s 2s/step - loss: 15.0276 - accuracy: 0.2251 - val_loss: 14.8889 - val_accuracy: 0.2078
# Epoch 11/90
# 43/43 [==============================] - 100s 2s/step - loss: 14.8456 - accuracy: 0.1848 - val_loss: 14.7018 - val_accuracy: 0.2297
# Epoch 12/90
# 43/43 [==============================] - 99s 2s/step - loss: 14.6593 - accuracy: 0.1987 - val_loss: 14.5221 - val_accuracy: 0.1937
# Epoch 13/90
# 43/43 [==============================] - 100s 2s/step - loss: 14.4761 - accuracy: 0.1922 - val_loss: 14.3377 - val_accuracy: 0.2109
# Epoch 14/90
# 43/43 [==============================] - 108s 3s/step - loss: 14.2919 - accuracy: 0.2098 - val_loss: 14.1556 - val_accuracy: 0.1719
# Epoch 15/90
# 43/43 [==============================] - 107s 2s/step - loss: 14.1093 - accuracy: 0.2096 - val_loss: 13.9698 - val_accuracy: 0.2172
# Epoch 16/90
# 43/43 [==============================] - 111s 3s/step - loss: 13.9256 - accuracy: 0.1993 - val_loss: 13.7881 - val_accuracy: 0.2281
# Epoch 17/90
# 43/43 [==============================] - 105s 2s/step - loss: 13.7430 - accuracy: 0.2081 - val_loss: 13.6076 - val_accuracy: 0.1937
# Epoch 18/90
# 43/43 [==============================] - 108s 3s/step - loss: 13.5630 - accuracy: 0.2076 - val_loss: 13.4274 - val_accuracy: 0.1891
# Epoch 19/90
# 43/43 [==============================] - 110s 3s/step - loss: 13.3806 - accuracy: 0.2176 - val_loss: 13.2445 - val_accuracy: 0.2062
# Epoch 20/90
# 43/43 [==============================] - 112s 3s/step - loss: 13.2014 - accuracy: 0.2081 - val_loss: 13.0661 - val_accuracy: 0.1813
# Epoch 21/90
# 43/43 [==============================] - 113s 3s/step - loss: 13.0221 - accuracy: 0.2078 - val_loss: 12.8871 - val_accuracy: 0.2141
# Epoch 22/90
# 43/43 [==============================] - 110s 3s/step - loss: 12.8419 - accuracy: 0.2204 - val_loss: 12.7078 - val_accuracy: 0.2344
# Epoch 23/90
# 43/43 [==============================] - 109s 3s/step - loss: 12.6654 - accuracy: 0.2104 - val_loss: 12.5333 - val_accuracy: 0.1984
# Epoch 24/90
# 43/43 [==============================] - 109s 3s/step - loss: 12.4867 - accuracy: 0.1953 - val_loss: 12.3567 - val_accuracy: 0.1844
# Epoch 25/90
# 43/43 [==============================] - 112s 3s/step - loss: 12.3115 - accuracy: 0.2217 - val_loss: 12.1802 - val_accuracy: 0.1875
# Epoch 26/90
# 43/43 [==============================] - 111s 3s/step - loss: 12.1363 - accuracy: 0.2206 - val_loss: 12.0036 - val_accuracy: 0.2297
# Epoch 27/90
# 43/43 [==============================] - 109s 3s/step - loss: 11.9629 - accuracy: 0.1849 - val_loss: 11.8320 - val_accuracy: 0.1844
# Epoch 28/90
# 43/43 [==============================] - 104s 2s/step - loss: 11.7880 - accuracy: 0.2128 - val_loss: 11.6630 - val_accuracy: 0.1859
# Epoch 29/90
# 43/43 [==============================] - 110s 3s/step - loss: 11.6176 - accuracy: 0.2188 - val_loss: 11.4880 - val_accuracy: 0.2047
# Epoch 30/90
# 43/43 [==============================] - 111s 3s/step - loss: 11.4459 - accuracy: 0.2157 - val_loss: 11.3203 - val_accuracy: 0.1766
# Epoch 31/90
# 43/43 [==============================] - 106s 2s/step - loss: 11.2778 - accuracy: 0.1964 - val_loss: 11.1501 - val_accuracy: 0.1797
# Epoch 32/90
# 43/43 [==============================] - 103s 2s/step - loss: 11.1095 - accuracy: 0.1907 - val_loss: 10.9848 - val_accuracy: 0.2000
# Epoch 33/90
# 43/43 [==============================] - 107s 2s/step - loss: 10.9424 - accuracy: 0.2055 - val_loss: 10.8191 - val_accuracy: 0.2016
# Epoch 34/90
# 43/43 [==============================] - 107s 2s/step - loss: 10.7777 - accuracy: 0.2153 - val_loss: 10.6574 - val_accuracy: 0.2000
# Epoch 35/90
# 43/43 [==============================] - 109s 3s/step - loss: 10.6149 - accuracy: 0.2162 - val_loss: 10.4934 - val_accuracy: 0.2062
# Epoch 36/90
# 43/43 [==============================] - 109s 3s/step - loss: 10.4528 - accuracy: 0.2151 - val_loss: 10.3335 - val_accuracy: 0.1937
# Epoch 37/90
# 43/43 [==============================] - 106s 2s/step - loss: 10.2930 - accuracy: 0.2053 - val_loss: 10.1742 - val_accuracy: 0.1859
# Epoch 38/90
# 43/43 [==============================] - 109s 3s/step - loss: 10.1320 - accuracy: 0.2225 - val_loss: 10.0158 - val_accuracy: 0.2188
# Epoch 39/90
# 43/43 [==============================] - 111s 3s/step - loss: 9.9756 - accuracy: 0.2010 - val_loss: 9.8593 - val_accuracy: 0.1969
# Epoch 40/90
# 43/43 [==============================] - 113s 3s/step - loss: 9.8217 - accuracy: 0.1965 - val_loss: 9.7044 - val_accuracy: 0.2172
# Epoch 41/90
# 43/43 [==============================] - 108s 3s/step - loss: 9.6668 - accuracy: 0.2055 - val_loss: 9.5534 - val_accuracy: 0.2047
# Epoch 42/90
# 43/43 [==============================] - 107s 2s/step - loss: 9.5141 - accuracy: 0.2045 - val_loss: 9.4015 - val_accuracy: 0.1969
# Epoch 43/90
# 43/43 [==============================] - 106s 2s/step - loss: 9.3642 - accuracy: 0.1984 - val_loss: 9.2531 - val_accuracy: 0.1844
# Epoch 44/90
# 43/43 [==============================] - 108s 3s/step - loss: 9.2159 - accuracy: 0.2008 - val_loss: 9.1063 - val_accuracy: 0.2188
# Epoch 45/90
# 43/43 [==============================] - 110s 3s/step - loss: 9.0696 - accuracy: 0.2136 - val_loss: 8.9614 - val_accuracy: 0.1891
# Epoch 46/90
# 43/43 [==============================] - 111s 3s/step - loss: 8.9252 - accuracy: 0.1938 - val_loss: 8.8178 - val_accuracy: 0.2078
# Epoch 47/90
# 43/43 [==============================] - 112s 3s/step - loss: 8.7826 - accuracy: 0.2114 - val_loss: 8.6774 - val_accuracy: 0.2125
# Epoch 48/90
# 43/43 [==============================] - 113s 3s/step - loss: 8.6428 - accuracy: 0.2063 - val_loss: 8.5418 - val_accuracy: 0.2109
# Epoch 49/90
# 43/43 [==============================] - 105s 2s/step - loss: 8.5058 - accuracy: 0.1957 - val_loss: 8.4041 - val_accuracy: 0.1875
# Epoch 50/90
# 43/43 [==============================] - 112s 3s/step - loss: 8.3736 - accuracy: 0.2052 - val_loss: 8.2739 - val_accuracy: 0.2047
# Epoch 51/90
# 43/43 [==============================] - 112s 3s/step - loss: 8.2418 - accuracy: 0.2121 - val_loss: 8.1455 - val_accuracy: 0.2141
# Epoch 52/90
# 43/43 [==============================] - 108s 2s/step - loss: 8.1144 - accuracy: 0.2118 - val_loss: 8.0200 - val_accuracy: 0.2125
# Epoch 53/90
# 43/43 [==============================] - 107s 2s/step - loss: 7.9938 - accuracy: 0.1861 - val_loss: 7.9008 - val_accuracy: 0.2219
# Epoch 54/90
# 37/43 [========================>.....] - ETA: 13s - loss: 7.8765 - accuracy: 0.1834
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-b4a8790f84c3> in <module>
#       1 # Training the model
# ----> 2 history2 = model_bayes2.fit(train_generator,
#       3                                 steps_per_epoch = train_generator.samples // batch_size,
#       4                                 validation_data = test_generator,
#       5                                 validation_steps = test_generator.samples // batch_size,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\anaconda3\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12, 3))
fig.suptitle("Bayesian Model 2's accuracy and Loss",fontsize=12)


ax1.plot(history2.history['accuracy'],label='train')
ax1.plot(history2.history['val_accuracy'],label='test')
ax1.title.set_text('model accuracy')
ax1.set_ylabel('accuracy')
ax1.set_xlabel('epoch')
ax1.legend()



ax2.plot(history2.history['loss'],label='train')
ax2.plot(history2.history['val_loss'],label='test')
ax2.title.set_text('model loss')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend()

# %% [markdown]
# ## Bayesian Model 3

# %%
divergence_fn = lambda q,p,_:tfd.kl_divergence(q,p)/train_generator.samples

model_bayes3 = tf.keras.Sequential([
    tf.keras.Input(shape=(img_width, img_height, 3),name="basket"),
    
    tfpl.Convolution2DFlipout(16, kernel_size=5, strides=(1,1), data_format="channels_last", 
                                    padding="same", activation=tf.nn.relu, name="conv_tfp_1a", 
                                    kernel_divergence_fn=divergence_fn),
    MaxPool2D(strides=(2,2), pool_size=(2,2), padding="same"),
    Conv2D(128, (3,3), activation='relu'),
    MaxPool2D(strides=(2,2), pool_size=(2,2), padding="same"),
    tfpl.Convolution2DFlipout(32, kernel_size=3, strides=(1,1), data_format="channels_last", 
                                    padding="same", activation=tf.nn.relu, name="conv_tfp_1b", 
                                    kernel_divergence_fn=divergence_fn),
    MaxPool2D(strides=(2,2), pool_size=(2,2), padding="same"),
    Conv2D(128, (3,3), activation='relu'),
    MaxPooling2D(2,2),
    Flatten(),
    Dense(1024, activation='relu'),
    Dense(512, activation='relu'),
    
    Dropout(0.2),
    tfpl.DenseFlipout(units=5, kernel_divergence_fn=divergence_fn),
    #tfpl.OneHotCategorical(5)
])

learning_rate = 1.0e-3


model_bayes3.summary()
# Out:
# C:\Users\obaid\anaconda3\lib\site-packages\tensorflow\python\keras\engine\base_layer.py:2281: UserWarning: `layer.add_variable` is deprecated and will be removed in a future version. Please use `layer.add_weight` method instead.
#   warnings.warn('`layer.add_variable` is deprecated and '
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv_tfp_1a (Conv2DFlipout)  (None, 256, 256, 16)      2416
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 128, 128, 16)      0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 126, 126, 128)     18560
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 63, 63, 128)       0
# _________________________________________________________________
# conv_tfp_1b (Conv2DFlipout)  (None, 63, 63, 32)        73760
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 32, 32, 32)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 30, 30, 128)       36992
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 15, 15, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 28800)             0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              29492224
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               524800
# _________________________________________________________________
# dropout (Dropout)            (None, 512)               0
# _________________________________________________________________
# dense_flipout (DenseFlipout) (None, 5)                 5125
# =================================================================
# Total params: 30,153,877
# Trainable params: 30,153,877
# Non-trainable params: 0
# _________________________________________________________________

# %%
#tf.config.experimental_run_functions_eagerly(False)

from keras import backend as K

# def negative_log_likelihood(y_true, y_pred):
#     return -y_pred.log_prob(y_true)

def loss_function(y_true, y_pred):
    #tf.print(y_true-y_pred[:])
    diff=abs(y_true-y_pred[:])
    diff=diff.numpy()
    #loss=np.sum(diff, axis=1);
    loss=np.sum(diff);
    #tf.print(np.shape(np.sum(diff, axis=1)))
    return loss

# model_bayes3.compile(loss = loss_function,
#               optimizer = Adam(learning_rate=0.005),
#               metrics = ['accuracy'],
#                     run_eagerly=True,
#               experimental_run_tf_function = False)


def negative_log_likelihood(y_true, y_pred):
    #tf.print(y_pred)
    y_pred = tfp.distributions.MultivariateNormalTriL(y_pred)
    return -tf.reduce_mean(y_pred.log_prob(y_true))

from keras import backend as K

def class0(y_true, y_pred):
    class_id_true = K.argmax(y_true, axis=-1)
    class_id_preds = K.argmax(y_pred, axis=-1)
    accuracy_mask = K.cast(K.equal(class_id_preds, 0), 'int32')
    class_acc_tensor = K.cast(K.equal(class_id_true, class_id_preds), 'int32') * accuracy_mask
    class_acc = K.sum(class_acc_tensor) / K.maximum(K.sum(accuracy_mask), 1)
    return class_acc

def class1(y_true, y_pred):
    class_id_true = K.argmax(y_true, axis=-1)
    class_id_preds = K.argmax(y_pred, axis=-1)
    accuracy_mask = K.cast(K.equal(class_id_preds, 1), 'int32')
    class_acc_tensor = K.cast(K.equal(class_id_true, class_id_preds), 'int32') * accuracy_mask
    class_acc = K.sum(class_acc_tensor) / K.maximum(K.sum(accuracy_mask), 1)
    return class_acc

def class2(y_true, y_pred):
    class_id_true = K.argmax(y_true, axis=-1)
    class_id_preds = K.argmax(y_pred, axis=-1)
    accuracy_mask = K.cast(K.equal(class_id_preds, 2), 'int32')
    class_acc_tensor = K.cast(K.equal(class_id_true, class_id_preds), 'int32') * accuracy_mask
    class_acc = K.sum(class_acc_tensor) / K.maximum(K.sum(accuracy_mask), 1)
    return class_acc

def class3(y_true, y_pred):
    class_id_true = K.argmax(y_true, axis=-1)
    class_id_preds = K.argmax(y_pred, axis=-1)
    accuracy_mask = K.cast(K.equal(class_id_preds, 3), 'int32')
    class_acc_tensor = K.cast(K.equal(class_id_true, class_id_preds), 'int32') * accuracy_mask
    class_acc = K.sum(class_acc_tensor) / K.maximum(K.sum(accuracy_mask), 1)
    return class_acc

def class4(y_true, y_pred):
    class_id_true = K.argmax(y_true, axis=-1)
    class_id_preds = K.argmax(y_pred, axis=-1)
    accuracy_mask = K.cast(K.equal(class_id_preds, 4), 'int32')
    class_acc_tensor = K.cast(K.equal(class_id_true, class_id_preds), 'int32') * accuracy_mask
    class_acc = K.sum(class_acc_tensor) / K.maximum(K.sum(accuracy_mask), 1)
    return class_acc

# %%
model_bayes3.compile(loss = negative_log_likelihood,
              optimizer = Adam(learning_rate=learning_rate),
              metrics=[tf.keras.metrics.CategoricalAccuracy(),class0,class1,class2,class3,class4],
              experimental_run_tf_function = False)

# %%
history3 = model_bayes3.fit(train_generator,
                                steps_per_epoch = train_generator.samples // batch_size,
                                validation_data = test_generator, 
                                validation_steps = test_generator.samples // batch_size,
                                epochs = 90)
# Out:
# Epoch 1/90
# 43/43 [==============================] - 264s 6s/step - loss: 41.1983 - categorical_accuracy: 0.1871 - class0: 0.2086 - class1: 0.1729 - class2: 0.1745 - class3: 0.1805 - class4: 0.2211 - val_loss: 40.9841 - val_categorical_accuracy: 0.1922 - val_class0: 0.1461 - val_class1: 0.2197 - val_class2: 0.2670 - val_class3: 0.1716 - val_class4: 0.1617
# Epoch 2/90
# 43/43 [==============================] - 262s 6s/step - loss: 40.7817 - categorical_accuracy: 0.2069 - class0: 0.2135 - class1: 0.1809 - class2: 0.1802 - class3: 0.2224 - class4: 0.1791 - val_loss: 40.5636 - val_categorical_accuracy: 0.1969 - val_class0: 0.1917 - val_class1: 0.2264 - val_class2: 0.1924 - val_class3: 0.2548 - val_class4: 0.1343
# Epoch 3/90
# 43/43 [==============================] - 262s 6s/step - loss: 40.3546 - categorical_accuracy: 0.2032 - class0: 0.2038 - class1: 0.1897 - class2: 0.2164 - class3: 0.1867 - class4: 0.2018 - val_loss: 40.1308 - val_categorical_accuracy: 0.2156 - val_class0: 0.1983 - val_class1: 0.2630 - val_class2: 0.2008 - val_class3: 0.1942 - val_class4: 0.2542
# Epoch 4/90
# 43/43 [==============================] - 261s 6s/step - loss: 39.9211 - categorical_accuracy: 0.1948 - class0: 0.2285 - class1: 0.1964 - class2: 0.1690 - class3: 0.2211 - class4: 0.1841 - val_loss: 39.6931 - val_categorical_accuracy: 0.2250 - val_class0: 0.1787 - val_class1: 0.2341 - val_class2: 0.1350 - val_class3: 0.2214 - val_class4: 0.2833
# Epoch 5/90
# 43/43 [==============================] - 250s 6s/step - loss: 39.4780 - categorical_accuracy: 0.2156 - class0: 0.2363 - class1: 0.2058 - class2: 0.2140 - class3: 0.2385 - class4: 0.2514 - val_loss: 39.2471 - val_categorical_accuracy: 0.2000 - val_class0: 0.2752 - val_class1: 0.2271 - val_class2: 0.1863 - val_class3: 0.1943 - val_class4: 0.1684
# Epoch 6/90
# 43/43 [==============================] - 232s 5s/step - loss: 39.0292 - categorical_accuracy: 0.2127 - class0: 0.2234 - class1: 0.2226 - class2: 0.2156 - class3: 0.2074 - class4: 0.2525 - val_loss: 38.7976 - val_categorical_accuracy: 0.2297 - val_class0: 0.2256 - val_class1: 0.2243 - val_class2: 0.1812 - val_class3: 0.2395 - val_class4: 0.3498
# Epoch 7/90
# 43/43 [==============================] - 228s 5s/step - loss: 38.5774 - categorical_accuracy: 0.2071 - class0: 0.2442 - class1: 0.1896 - class2: 0.2072 - class3: 0.2090 - class4: 0.1980 - val_loss: 38.3407 - val_categorical_accuracy: 0.2125 - val_class0: 0.1886 - val_class1: 0.2302 - val_class2: 0.0833 - val_class3: 0.3550 - val_class4: 0.2008
# Epoch 8/90
# 43/43 [==============================] - 225s 5s/step - loss: 38.1196 - categorical_accuracy: 0.2050 - class0: 0.2089 - class1: 0.2116 - class2: 0.1873 - class3: 0.1880 - class4: 0.2336 - val_loss: 37.8829 - val_categorical_accuracy: 0.2125 - val_class0: 0.1255 - val_class1: 0.2381 - val_class2: 0.1573 - val_class3: 0.2100 - val_class4: 0.2476
# Epoch 9/90
# 43/43 [==============================] - 226s 5s/step - loss: 37.6590 - categorical_accuracy: 0.2105 - class0: 0.2022 - class1: 0.2281 - class2: 0.1803 - class3: 0.1912 - class4: 0.2242 - val_loss: 37.4196 - val_categorical_accuracy: 0.2375 - val_class0: 0.2123 - val_class1: 0.1650 - val_class2: 0.2060 - val_class3: 0.2471 - val_class4: 0.2807
# Epoch 10/90
# 43/43 [==============================] - 221s 5s/step - loss: 37.1961 - categorical_accuracy: 0.2197 - class0: 0.2292 - class1: 0.2079 - class2: 0.2562 - class3: 0.2331 - class4: 0.2126 - val_loss: 36.9568 - val_categorical_accuracy: 0.2203 - val_class0: 0.2007 - val_class1: 0.2202 - val_class2: 0.2214 - val_class3: 0.2150 - val_class4: 0.2754
# Epoch 11/90
# 43/43 [==============================] - 233s 5s/step - loss: 36.7291 - categorical_accuracy: 0.2314 - class0: 0.2031 - class1: 0.2238 - class2: 0.2524 - class3: 0.2395 - class4: 0.2370 - val_loss: 36.4889 - val_categorical_accuracy: 0.2484 - val_class0: 0.2780 - val_class1: 0.2368 - val_class2: 0.1935 - val_class3: 0.2422 - val_class4: 0.2547
# Epoch 12/90
# 43/43 [==============================] - 242s 6s/step - loss: 36.2634 - categorical_accuracy: 0.2244 - class0: 0.2049 - class1: 0.2331 - class2: 0.2199 - class3: 0.2228 - class4: 0.2512 - val_loss: 36.0227 - val_categorical_accuracy: 0.2281 - val_class0: 0.2266 - val_class1: 0.2417 - val_class2: 0.2091 - val_class3: 0.2102 - val_class4: 0.2160
# Epoch 13/90
# 43/43 [==============================] - 246s 6s/step - loss: 35.7935 - categorical_accuracy: 0.2398 - class0: 0.1860 - class1: 0.2743 - class2: 0.2469 - class3: 0.2557 - class4: 0.2482 - val_loss: 35.5491 - val_categorical_accuracy: 0.2562 - val_class0: 0.2496 - val_class1: 0.2814 - val_class2: 0.1717 - val_class3: 0.2650 - val_class4: 0.2775
# Epoch 14/90
# 43/43 [==============================] - 234s 5s/step - loss: 35.3217 - categorical_accuracy: 0.2387 - class0: 0.2718 - class1: 0.2393 - class2: 0.2256 - class3: 0.2545 - class4: 0.2263 - val_loss: 35.0823 - val_categorical_accuracy: 0.2016 - val_class0: 0.2075 - val_class1: 0.1990 - val_class2: 0.1599 - val_class3: 0.2335 - val_class4: 0.2344
# Epoch 15/90
# 43/43 [==============================] - 224s 5s/step - loss: 34.8514 - categorical_accuracy: 0.2219 - class0: 0.2154 - class1: 0.2236 - class2: 0.2249 - class3: 0.2406 - class4: 0.2321 - val_loss: 34.6058 - val_categorical_accuracy: 0.2156 - val_class0: 0.2132 - val_class1: 0.2117 - val_class2: 0.1933 - val_class3: 0.2186 - val_class4: 0.2211
# Epoch 16/90
# 43/43 [==============================] - 224s 5s/step - loss: 34.3793 - categorical_accuracy: 0.2343 - class0: 0.2198 - class1: 0.2745 - class2: 0.2163 - class3: 0.2019 - class4: 0.2689 - val_loss: 34.1342 - val_categorical_accuracy: 0.2500 - val_class0: 0.3067 - val_class1: 0.3069 - val_class2: 0.2838 - val_class3: 0.2239 - val_class4: 0.2305
# Epoch 17/90
# 43/43 [==============================] - 222s 5s/step - loss: 33.9020 - categorical_accuracy: 0.2442 - class0: 0.2034 - class1: 0.2278 - class2: 0.2141 - class3: 0.2572 - class4: 0.2590 - val_loss: 33.6624 - val_categorical_accuracy: 0.2266 - val_class0: 0.2171 - val_class1: 0.1739 - val_class2: 0.1556 - val_class3: 0.2853 - val_class4: 0.2439
# Epoch 18/90
# 43/43 [==============================] - 223s 5s/step - loss: 33.4290 - categorical_accuracy: 0.2515 - class0: 0.2549 - class1: 0.2800 - class2: 0.2154 - class3: 0.2397 - class4: 0.2741 - val_loss: 33.1904 - val_categorical_accuracy: 0.2203 - val_class0: 0.2581 - val_class1: 0.1707 - val_class2: 0.2177 - val_class3: 0.2896 - val_class4: 0.2610
# Epoch 19/90
# 43/43 [==============================] - 239s 6s/step - loss: 32.9548 - categorical_accuracy: 0.2529 - class0: 0.2337 - class1: 0.2897 - class2: 0.2413 - class3: 0.2457 - class4: 0.2711 - val_loss: 32.7137 - val_categorical_accuracy: 0.2531 - val_class0: 0.2586 - val_class1: 0.2773 - val_class2: 0.2666 - val_class3: 0.2566 - val_class4: 0.2526
# Epoch 20/90
# 43/43 [==============================] - 235s 5s/step - loss: 32.4786 - categorical_accuracy: 0.2654 - class0: 0.2418 - class1: 0.2991 - class2: 0.2310 - class3: 0.2620 - class4: 0.2838 - val_loss: 32.2383 - val_categorical_accuracy: 0.2188 - val_class0: 0.2207 - val_class1: 0.2451 - val_class2: 0.1694 - val_class3: 0.2490 - val_class4: 0.2322
# Epoch 21/90
# 43/43 [==============================] - 251s 6s/step - loss: 32.0084 - categorical_accuracy: 0.2474 - class0: 0.2552 - class1: 0.2584 - class2: 0.2289 - class3: 0.2749 - class4: 0.2710 - val_loss: 31.7635 - val_categorical_accuracy: 0.2453 - val_class0: 0.2585 - val_class1: 0.2273 - val_class2: 0.1767 - val_class3: 0.2190 - val_class4: 0.2623
# Epoch 22/90
# 43/43 [==============================] - 251s 6s/step - loss: 31.5302 - categorical_accuracy: 0.2657 - class0: 0.2595 - class1: 0.2764 - class2: 0.2474 - class3: 0.2596 - class4: 0.2863 - val_loss: 31.2915 - val_categorical_accuracy: 0.2469 - val_class0: 0.2187 - val_class1: 0.2491 - val_class2: 0.1517 - val_class3: 0.2255 - val_class4: 0.2637
# Epoch 23/90
# 43/43 [==============================] - 227s 5s/step - loss: 31.0577 - categorical_accuracy: 0.2661 - class0: 0.2423 - class1: 0.2923 - class2: 0.2594 - class3: 0.2726 - class4: 0.2770 - val_loss: 30.8196 - val_categorical_accuracy: 0.2031 - val_class0: 0.2222 - val_class1: 0.1363 - val_class2: 0.2057 - val_class3: 0.1813 - val_class4: 0.2685
# Epoch 24/90
# 43/43 [==============================] - 231s 5s/step - loss: 30.5847 - categorical_accuracy: 0.2416 - class0: 0.2618 - class1: 0.2611 - class2: 0.2071 - class3: 0.2420 - class4: 0.3067 - val_loss: 30.3448 - val_categorical_accuracy: 0.2531 - val_class0: 0.2052 - val_class1: 0.2594 - val_class2: 0.2701 - val_class3: 0.2997 - val_class4: 0.2753
# Epoch 25/90
# 43/43 [==============================] - 234s 5s/step - loss: 30.1111 - categorical_accuracy: 0.2749 - class0: 0.2453 - class1: 0.3079 - class2: 0.2474 - class3: 0.2771 - class4: 0.3087 - val_loss: 29.8733 - val_categorical_accuracy: 0.2609 - val_class0: 0.1947 - val_class1: 0.3171 - val_class2: 0.1584 - val_class3: 0.2379 - val_class4: 0.3114
# Epoch 26/90
# 43/43 [==============================] - 233s 5s/step - loss: 29.6386 - categorical_accuracy: 0.2913 - class0: 0.2782 - class1: 0.3162 - class2: 0.2529 - class3: 0.3058 - class4: 0.3005 - val_loss: 29.4078 - val_categorical_accuracy: 0.2141 - val_class0: 0.1810 - val_class1: 0.2339 - val_class2: 0.2142 - val_class3: 0.2867 - val_class4: 0.2033
# Epoch 27/90
# 43/43 [==============================] - 236s 5s/step - loss: 29.1683 - categorical_accuracy: 0.2862 - class0: 0.2436 - class1: 0.2774 - class2: 0.2509 - class3: 0.3179 - class4: 0.3167 - val_loss: 28.9369 - val_categorical_accuracy: 0.2453 - val_class0: 0.2024 - val_class1: 0.2843 - val_class2: 0.1897 - val_class3: 0.2998 - val_class4: 0.2631
# Epoch 28/90
# 43/43 [==============================] - 225s 5s/step - loss: 28.6997 - categorical_accuracy: 0.2822 - class0: 0.2783 - class1: 0.3099 - class2: 0.1979 - class3: 0.3000 - class4: 0.3239 - val_loss: 28.4642 - val_categorical_accuracy: 0.2891 - val_class0: 0.2695 - val_class1: 0.2641 - val_class2: 0.2551 - val_class3: 0.3144 - val_class4: 0.3679
# Epoch 29/90
# 43/43 [==============================] - 224s 5s/step - loss: 28.2305 - categorical_accuracy: 0.3004 - class0: 0.3279 - class1: 0.3098 - class2: 0.3006 - class3: 0.2787 - class4: 0.3344 - val_loss: 27.9990 - val_categorical_accuracy: 0.2734 - val_class0: 0.1987 - val_class1: 0.2683 - val_class2: 0.1997 - val_class3: 0.2921 - val_class4: 0.3221
# Epoch 30/90
# 43/43 [==============================] - 223s 5s/step - loss: 27.7620 - categorical_accuracy: 0.3001 - class0: 0.2782 - class1: 0.3064 - class2: 0.2404 - class3: 0.3059 - class4: 0.3527 - val_loss: 27.5379 - val_categorical_accuracy: 0.2656 - val_class0: 0.1981 - val_class1: 0.2918 - val_class2: 0.1800 - val_class3: 0.2836 - val_class4: 0.3003
# Epoch 31/90
# 43/43 [==============================] - 221s 5s/step - loss: 27.2976 - categorical_accuracy: 0.3162 - class0: 0.2774 - class1: 0.3108 - class2: 0.3251 - class3: 0.3188 - class4: 0.3615 - val_loss: 27.0771 - val_categorical_accuracy: 0.2547 - val_class0: 0.2180 - val_class1: 0.2469 - val_class2: 0.2125 - val_class3: 0.2309 - val_class4: 0.3534
# Epoch 32/90
# 43/43 [==============================] - 221s 5s/step - loss: 26.8329 - categorical_accuracy: 0.3282 - class0: 0.3157 - class1: 0.3282 - class2: 0.2730 - class3: 0.3328 - class4: 0.3633 - val_loss: 26.6180 - val_categorical_accuracy: 0.2844 - val_class0: 0.2134 - val_class1: 0.2902 - val_class2: 0.2912 - val_class3: 0.3232 - val_class4: 0.3326
# Epoch 33/90
# 43/43 [==============================] - 8477s 202s/step - loss: 26.3741 - categorical_accuracy: 0.3257 - class0: 0.3317 - class1: 0.3300 - class2: 0.2565 - class3: 0.3610 - class4: 0.3827 - val_loss: 26.1593 - val_categorical_accuracy: 0.2625 - val_class0: 0.1769 - val_class1: 0.3179 - val_class2: 0.1212 - val_class3: 0.3416 - val_class4: 0.2793
# Epoch 34/90
# 43/43 [==============================] - 233s 5s/step - loss: 25.9167 - categorical_accuracy: 0.3352 - class0: 0.2986 - class1: 0.3451 - class2: 0.3025 - class3: 0.3285 - class4: 0.3787 - val_loss: 25.7041 - val_categorical_accuracy: 0.2531 - val_class0: 0.2183 - val_class1: 0.2353 - val_class2: 0.1752 - val_class3: 0.2438 - val_class4: 0.3506
# Epoch 35/90
# 43/43 [==============================] - 228s 5s/step - loss: 25.4610 - categorical_accuracy: 0.3490 - class0: 0.2937 - class1: 0.3609 - class2: 0.3410 - class3: 0.3567 - class4: 0.4268 - val_loss: 25.2564 - val_categorical_accuracy: 0.2406 - val_class0: 0.1784 - val_class1: 0.2377 - val_class2: 0.2400 - val_class3: 0.2645 - val_class4: 0.3624
# Epoch 36/90
# 43/43 [==============================] - 224s 5s/step - loss: 25.0080 - categorical_accuracy: 0.3450 - class0: 0.3051 - class1: 0.3471 - class2: 0.3030 - class3: 0.3490 - class4: 0.4036 - val_loss: 24.7994 - val_categorical_accuracy: 0.2781 - val_class0: 0.2337 - val_class1: 0.2846 - val_class2: 0.2651 - val_class3: 0.3033 - val_class4: 0.3572
# Epoch 37/90
# 43/43 [==============================] - 224s 5s/step - loss: 24.5516 - categorical_accuracy: 0.3754 - class0: 0.3424 - class1: 0.3774 - class2: 0.3511 - class3: 0.3883 - class4: 0.4314 - val_loss: 24.3621 - val_categorical_accuracy: 0.2688 - val_class0: 0.2460 - val_class1: 0.2965 - val_class2: 0.1658 - val_class3: 0.2581 - val_class4: 0.3176
# Epoch 38/90
# 43/43 [==============================] - 220s 5s/step - loss: 24.1076 - categorical_accuracy: 0.3615 - class0: 0.3146 - class1: 0.3948 - class2: 0.3105 - class3: 0.3568 - class4: 0.4113 - val_loss: 23.9179 - val_categorical_accuracy: 0.2531 - val_class0: 0.2191 - val_class1: 0.2025 - val_class2: 0.2094 - val_class3: 0.2567 - val_class4: 0.3262
# Epoch 39/90
# 43/43 [==============================] - 219s 5s/step - loss: 23.6620 - categorical_accuracy: 0.3816 - class0: 0.3539 - class1: 0.3937 - class2: 0.3246 - class3: 0.3784 - class4: 0.4502 - val_loss: 23.4745 - val_categorical_accuracy: 0.2812 - val_class0: 0.2548 - val_class1: 0.3107 - val_class2: 0.2055 - val_class3: 0.2841 - val_class4: 0.3091
# Epoch 40/90
# 43/43 [==============================] - 218s 5s/step - loss: 23.2186 - categorical_accuracy: 0.3845 - class0: 0.3165 - class1: 0.3897 - class2: 0.3286 - class3: 0.3991 - class4: 0.4684 - val_loss: 23.0382 - val_categorical_accuracy: 0.2719 - val_class0: 0.2083 - val_class1: 0.2873 - val_class2: 0.1558 - val_class3: 0.2856 - val_class4: 0.3885
# Epoch 41/90
# 43/43 [==============================] - 219s 5s/step - loss: 22.7841 - categorical_accuracy: 0.4006 - class0: 0.3549 - class1: 0.4116 - class2: 0.3776 - class3: 0.4335 - class4: 0.4552 - val_loss: 22.6094 - val_categorical_accuracy: 0.2484 - val_class0: 0.1665 - val_class1: 0.2397 - val_class2: 0.2612 - val_class3: 0.2347 - val_class4: 0.3244
# Epoch 42/90
# 43/43 [==============================] - 219s 5s/step - loss: 22.3514 - categorical_accuracy: 0.4035 - class0: 0.3664 - class1: 0.4087 - class2: 0.4019 - class3: 0.4098 - class4: 0.4488 - val_loss: 22.1799 - val_categorical_accuracy: 0.2625 - val_class0: 0.2150 - val_class1: 0.2998 - val_class2: 0.2017 - val_class3: 0.2414 - val_class4: 0.3202
# Epoch 43/90
# 43/43 [==============================] - 2295s 55s/step - loss: 21.9177 - categorical_accuracy: 0.4137 - class0: 0.3585 - class1: 0.4138 - class2: 0.3972 - class3: 0.4379 - class4: 0.4850 - val_loss: 21.7599 - val_categorical_accuracy: 0.2828 - val_class0: 0.2748 - val_class1: 0.2698 - val_class2: 0.2744 - val_class3: 0.2707 - val_class4: 0.3177
# Epoch 44/90
# 43/43 [==============================] - 227s 5s/step - loss: 21.4934 - categorical_accuracy: 0.4430 - class0: 0.4023 - class1: 0.4268 - class2: 0.4273 - class3: 0.4694 - class4: 0.5053 - val_loss: 21.3400 - val_categorical_accuracy: 0.2859 - val_class0: 0.2292 - val_class1: 0.2947 - val_class2: 0.1681 - val_class3: 0.3041 - val_class4: 0.3384
# Epoch 45/90
# 43/43 [==============================] - 225s 5s/step - loss: 21.0698 - categorical_accuracy: 0.4499 - class0: 0.4039 - class1: 0.4643 - class2: 0.4462 - class3: 0.4546 - class4: 0.5138 - val_loss: 20.9266 - val_categorical_accuracy: 0.2609 - val_class0: 0.1825 - val_class1: 0.2748 - val_class2: 0.2208 - val_class3: 0.3081 - val_class4: 0.3425
# Epoch 46/90
# 43/43 [==============================] - 225s 5s/step - loss: 20.6585 - categorical_accuracy: 0.4437 - class0: 0.4098 - class1: 0.4367 - class2: 0.4246 - class3: 0.4601 - class4: 0.5216 - val_loss: 20.5103 - val_categorical_accuracy: 0.2672 - val_class0: 0.2354 - val_class1: 0.3015 - val_class2: 0.2127 - val_class3: 0.2680 - val_class4: 0.3288
# Epoch 47/90
# 43/43 [==============================] - 225s 5s/step - loss: 20.2463 - categorical_accuracy: 0.4423 - class0: 0.3846 - class1: 0.4275 - class2: 0.4070 - class3: 0.4746 - class4: 0.5194 - val_loss: 20.1122 - val_categorical_accuracy: 0.2781 - val_class0: 0.2346 - val_class1: 0.2877 - val_class2: 0.1970 - val_class3: 0.2682 - val_class4: 0.3622
# Epoch 48/90
# 43/43 [==============================] - 221s 5s/step - loss: 19.8390 - categorical_accuracy: 0.4609 - class0: 0.4147 - class1: 0.4394 - class2: 0.4413 - class3: 0.4767 - class4: 0.5498 - val_loss: 19.7065 - val_categorical_accuracy: 0.2547 - val_class0: 0.2303 - val_class1: 0.2360 - val_class2: 0.1529 - val_class3: 0.2360 - val_class4: 0.3667
# Epoch 49/90
# 43/43 [==============================] - 222s 5s/step - loss: 19.4336 - categorical_accuracy: 0.4722 - class0: 0.4274 - class1: 0.4505 - class2: 0.4354 - class3: 0.4524 - class4: 0.5915 - val_loss: 19.3170 - val_categorical_accuracy: 0.2547 - val_class0: 0.2275 - val_class1: 0.2618 - val_class2: 0.1576 - val_class3: 0.2825 - val_class4: 0.3333
# Epoch 50/90
# 43/43 [==============================] - 221s 5s/step - loss: 19.0320 - categorical_accuracy: 0.4879 - class0: 0.4457 - class1: 0.4844 - class2: 0.4646 - class3: 0.4811 - class4: 0.5824 - val_loss: 18.9324 - val_categorical_accuracy: 0.2812 - val_class0: 0.2403 - val_class1: 0.2470 - val_class2: 0.2546 - val_class3: 0.2354 - val_class4: 0.3680
# Epoch 51/90
# 43/43 [==============================] - 220s 5s/step - loss: 18.6455 - categorical_accuracy: 0.5044 - class0: 0.4674 - class1: 0.4845 - class2: 0.4947 - class3: 0.5025 - class4: 0.5869 - val_loss: 18.5388 - val_categorical_accuracy: 0.2609 - val_class0: 0.2309 - val_class1: 0.2573 - val_class2: 0.1597 - val_class3: 0.2294 - val_class4: 0.3363
# Epoch 52/90
# 43/43 [==============================] - 220s 5s/step - loss: 18.2572 - categorical_accuracy: 0.4993 - class0: 0.4688 - class1: 0.5042 - class2: 0.4629 - class3: 0.5410 - class4: 0.5620 - val_loss: 18.1628 - val_categorical_accuracy: 0.2766 - val_class0: 0.2277 - val_class1: 0.2564 - val_class2: 0.1837 - val_class3: 0.2917 - val_class4: 0.3868
# Epoch 53/90
# 43/43 [==============================] - 1751s 42s/step - loss: 17.8746 - categorical_accuracy: 0.5270 - class0: 0.4860 - class1: 0.5440 - class2: 0.5235 - class3: 0.5208 - class4: 0.6086 - val_loss: 17.7795 - val_categorical_accuracy: 0.2906 - val_class0: 0.2510 - val_class1: 0.2781 - val_class2: 0.2058 - val_class3: 0.2926 - val_class4: 0.3662
# Epoch 54/90
# 16/43 [==========>...................] - ETA: 2:38 - loss: 17.6167 - categorical_accuracy: 0.5322 - class0: 0.4946 - class1: 0.4835 - class2: 0.5219 - class3: 0.5069 - class4: 0.6762

# %%
fig, (ax1,ax2) = plt.subplots(1,2,figsize=(12, 3))
fig.suptitle("Bayesian Model 3's accuracy and Loss",fontsize=12)


ax1.plot(history3.history['categorical_accuracy'],label='train')
ax1.plot(history3.history['val_categorical_accuracy'],label='test')
ax1.title.set_text('model categorical_accuracy')
ax1.set_ylabel('categorical_accuracy')
ax1.set_xlabel('epoch')
ax1.legend()



ax2.plot(history3.history['loss'],label='train')
ax2.plot(history3.history['val_loss'],label='test')
ax2.title.set_text('model loss')
ax2.set_ylabel('loss')
ax2.set_xlabel('epoch')
ax2.legend()

# %%
np.savez("history_plots.npz",history.history,history2.history,history3.history)

# %% [markdown]
# ## 4 Display Function 1

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

def import_and_predict_bayes(image, true_label):

    #read image
    img = cv2.imread(image)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    
    #show the image
    plt.imshow(img)
    plt.axis('off')
    
    img_resize = (cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_CUBIC))/255.
    
    predicted_probabilities = np.empty(shape=(300, 5))
    predicted_probabilities2 = np.empty(shape=(300, 5))
    predicted_probabilities3 = np.empty(shape=(300, 5))
    for i in range(300):
       
        predicted_probabilities2[i] =model_bayes3.predict(img_resize[np.newaxis,...])   
        
    pct_2p5 = np.array([np.percentile(predicted_probabilities2[:, i], 2.5) for i in range(5)])
    pct_97p5 = np.array([np.percentile(predicted_probabilities2[:, i], 97.5) for i in range(5)])
    
    fig, ax = plt.subplots(figsize=(12, 6))
    bar = ax.bar(np.arange(5), pct_97p5, color='red')
    bar[true_label].set_color('green')
    bar = ax.bar(np.arange(5), pct_2p5-0.02, color='white')
    ax.set_xticklabels([''] + [x for x in label])
    ax.set_ylim([0, 1])
    ax.set_ylabel('Probability')
    plt.show()

# %%
label = os.listdir(root_dir)
image1_dir = os.path.join(root_dir+'/1/1145_left.jpeg')
image2_dir = os.path.join(root_dir+'/0/62_left.jpeg')
image3_dir = os.path.join(root_dir+'/4/8462_right.jpeg')
image4_dir = os.path.join(root_dir+'/3/37354_right.jpeg')

prediction = import_and_predict_bayes(image2_dir,  label.index('0'))
# Out:
# <ipython-input-62-a17cefc3a24e>:31: UserWarning: FixedFormatter should only be used together with FixedLocator
#   ax.set_xticklabels([''] + [x for x in label])

# %% [markdown]
# ## 5 Display Function 2

# %%
def import_and_predict2(image_data, label, T):
    
    #read image
    img = cv2.imread(image_data)
    img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
    
    #show the image
    #plt.imshow(img)
    #plt.axis('off')
    
    # resize and reshape the image
    
    img_resize = (cv2.resize(img, dsize=(256, 256), interpolation=cv2.INTER_CUBIC))/255.
    
    img_reshape = img_resize[np.newaxis,...]
    
    #predict the image
   

    prediction = model_bayes2.predict(img_reshape)    
    
    p_hat=[]
    for t in range (T):
        p_hat.append(model_bayes3.predict(img_reshape)[0])
    p_hat=np.array(p_hat)
       
    prediction = np.mean(p_hat, axis=0)
    label_prediction = label[np.argmax(prediction)]
    aleatoric = np.mean(p_hat*(1-p_hat), axis=0)
    epistemic = np.mean(p_hat**2, axis=0) - np.mean(p_hat, axis=0)**2
    
    label_prediction = [np.argmax(prediction)]
    
    return prediction, label_prediction, aleatoric, epistemic

# %%
# Out:
# ['0', '1', '2', '3', '4']

# %%
T=10
label = os.listdir(root_dir)
image_dir = os.path.join(root_dir+'/1/1145_left.jpeg')
prediction, label_prediction, aleatoric, epistemic =import_and_predict2(image_dir, label,T)
print(epistemic)
print(label_prediction)
# Out:
# [0.00060333 0.00076715 0.00131298 0.00051029 0.00287569]
# [3]

# %%
input_dir=root_dir
Class_Names=["0","1","2","3","4"]
total_prediction=np.empty(5)
total_label_prediction=np.empty(1)
total_aleatoric=np.empty(5)
total_epistemic=np.empty(5)
total_accuracy=np.empty(1)
total_tracker=np.empty(1)
tracker=np.empty(1)

for Class in Class_Names:
    path = os.path.join(input_dir,Class)
    files = os.listdir(path)
    for file in files:
        T=10 # T should be 2 or greater
        
        image_dir=os.path.join(path,file)
        #print(image_dir)
        prediction, label_prediction, aleatoric, epistemic=import_and_predict2(image_dir, label,T)                        
        total_prediction=np.vstack((total_prediction,prediction))
        total_label_prediction=np.vstack((total_label_prediction,label_prediction))
        total_aleatoric=np.vstack((total_aleatoric,aleatoric))
        total_epistemic=np.vstack((total_epistemic,epistemic))
        tracker=Class_Names.index(Class)
        total_tracker=np.vstack((total_tracker,tracker))
                            
        if(int("".join(map(str, label_prediction)))==Class_Names.index(Class)):
                total_accuracy=np.vstack((total_accuracy,1))
        else: 
                total_accuracy=np.vstack((total_accuracy,0))

# %%
print (total_prediction.shape)
print (total_label_prediction.shape)
print (total_aleatoric.shape)
print (total_epistemic.shape)
print (total_accuracy.shape)
print (total_tracker.shape)
# Out:
# (3501, 5)
# (3501, 1)
# (3501, 5)
# (3501, 5)
# (3501, 1)
# (3501, 1)

# %%
total_prediction1=total_prediction[1:,:]
total_label_prediction1=total_label_prediction[1:,:]
total_aleatoric1=total_aleatoric[1:,:]
total_epistemic1=total_epistemic[1:,:]
total_accuracy1=total_accuracy[1:,:]
total_tracker1=total_tracker[1:,:]

# %%
print (total_prediction1.shape)
print (total_label_prediction1.shape)
print (total_aleatoric1.shape)
print (total_epistemic1.shape)
print (total_accuracy1.shape)
print(total_tracker1.shape)
# Out:
# (3500, 5)
# (3500, 1)
# (3500, 5)
# (3500, 5)
# (3500, 1)
# (3500, 1)

# %%
plt.plot(total_accuracy1[700:800,:])
#plt.plot(total_tracker1)
#plt.plot(total_accuracy1)

# %%
np.savez("dataDR_bayes3_700.npz",total_prediction1,total_label_prediction1,total_aleatoric1,total_epistemic1,total_accuracy1,total_tracker1)
